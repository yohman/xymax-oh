# %%
import geopandas as gpd

tokyo_gdf = gpd.read_file("tokyo.geojson")

# %%
for col in tokyo_gdf.columns:
    print(f"- {col}")
# Out:
# - KEY_CODE
# - 2023_building_count
# - 2023_office_count
# - 2023_commercial_count
# - 2023_hotel_count
# - 2023_house_count
# - 2023_apartment_count
# - 2023_logistics_count
# - 2023_office_total_use_area
# - 2023_commercial_total_use_area
# - 2023_hotel_total_use_area
# - 2023_house_total_use_area
# - 2023_apartment_total_use_area
# - 2023_logistics_total_use_area
# - 2023_total_use_area
# - 1996_building_count
# - 2001_building_count
# - 2006_building_count
# - 2011_building_count
# - 2016_building_count
# - 2023_old__building_count
# - 1996_office_count
# - 2001_office_count
# - 2006_office_count
# - 2011_office_count
# - 2016_office_count
# - 2023_old__office_count
# - 1996_commercial_count
# - 2001_commercial_count
# - 2006_commercial_count
# - 2011_commercial_count
# - 2016_commercial_count
# - 2023_old__commercial_count
# - 1996_hotel_count
# - 2001_hotel_count
# - 2006_hotel_count
# - 2011_hotel_count
# - 2016_hotel_count
# - 2023_old__hotel_count
# - 1996_house_count
# - 2001_house_count
# - 2006_house_count
# - 2011_house_count
# - 2016_house_count
# - 2023_old__house_count
# - 1996_apartment_count
# - 2001_apartment_count
# - 2006_apartment_count
# - 2011_apartment_count
# - 2016_apartment_count
# - 2023_old__apartment_count
# - 1996_logistics_count
# - 2001_logistics_count
# - 2006_logistics_count
# - 2011_logistics_count
# - 2016_logistics_count
# - 2023_old__logistics_count
# - 1996_office_total_use_area
# - 2001_office_total_use_area
# - 2006_office_total_use_area
# - 2011_office_total_use_area
# - 2016_office_total_use_area
# - 2023_old__office_total_use_area
# - 1996_commercial_total_use_area
# - 2001_commercial_total_use_area
# - 2006_commercial_total_use_area
# - 2011_commercial_total_use_area
# - 2016_commercial_total_use_area
# - 2023_old__commercial_total_use_area
# - 1996_hotel_total_use_area
# - 2001_hotel_total_use_area
# - 2006_hotel_total_use_area
# - 2011_hotel_total_use_area
# - 2016_hotel_total_use_area
# - 2023_old__hotel_total_use_area
# - 1996_house_total_use_area
# - 2001_house_total_use_area
# - 2006_house_total_use_area
# - 2011_house_total_use_area
# - 2016_house_total_use_area
# - 2023_old__house_total_use_area
# - 1996_apartment_total_use_area
# - 2001_apartment_total_use_area
# - 2006_apartment_total_use_area
# - 2011_apartment_total_use_area
# - 2016_apartment_total_use_area
# - 2023_old__apartment_total_use_area
# - 1996_logistics_total_use_area
# - 2001_logistics_total_use_area
# - 2006_logistics_total_use_area
# - 2011_logistics_total_use_area
# - 2016_logistics_total_use_area
# - 2023_old__logistics_total_use_area
# - 1996_total_use_area
# - 2001_total_use_area
# - 2006_total_use_area
# - 2011_total_use_area
# - 2016_total_use_area
# - 2023_old__total_use_area
# - 2023_building_count_percentile
# - 2023_office_count_percentile
# - 2023_commercial_count_percentile
# - 2023_hotel_count_percentile
# - 2023_house_count_percentile
# - 2023_apartment_count_percentile
# - 2023_logistics_count_percentile
# - 2023_office_total_use_area_percentile
# - 2023_commercial_total_use_area_percentile
# - 2023_hotel_total_use_area_percentile
# - 2023_house_total_use_area_percentile
# - 2023_apartment_total_use_area_percentile
# - 2023_logistics_total_use_area_percentile
# - 2023_total_use_area_percentile
# - 1996_building_count_percentile
# - 2001_building_count_percentile
# - 2006_building_count_percentile
# - 2011_building_count_percentile
# - 2016_building_count_percentile
# - 2023_old__building_count_percentile
# - 1996_office_count_percentile
# - 2001_office_count_percentile
# - 2006_office_count_percentile
# - 2011_office_count_percentile
# - 2016_office_count_percentile
# - 2023_old__office_count_percentile
# - 1996_commercial_count_percentile
# - 2001_commercial_count_percentile
# - 2006_commercial_count_percentile
# - 2011_commercial_count_percentile
# - 2016_commercial_count_percentile
# - 2023_old__commercial_count_percentile
# - 1996_hotel_count_percentile
# - 2001_hotel_count_percentile
# - 2006_hotel_count_percentile
# - 2011_hotel_count_percentile
# - 2016_hotel_count_percentile
# - 2023_old__hotel_count_percentile
# - 1996_house_count_percentile
# - 2001_house_count_percentile
# - 2006_house_count_percentile
# - 2011_house_count_percentile
# - 2016_house_count_percentile
# - 2023_old__house_count_percentile
# - 1996_apartment_count_percentile
# - 2001_apartment_count_percentile
# - 2006_apartment_count_percentile
# - 2011_apartment_count_percentile
# - 2016_apartment_count_percentile
# - 2023_old__apartment_count_percentile
# - 1996_logistics_count_percentile
# - 2001_logistics_count_percentile
# - 2006_logistics_count_percentile
# - 2011_logistics_count_percentile
# - 2016_logistics_count_percentile
# - 2023_old__logistics_count_percentile
# - 1996_office_total_use_area_percentile
# - 2001_office_total_use_area_percentile
# - 2006_office_total_use_area_percentile
# - 2011_office_total_use_area_percentile
# - 2016_office_total_use_area_percentile
# - 2023_old__office_total_use_area_percentile
# - 1996_commercial_total_use_area_percentile
# - 2001_commercial_total_use_area_percentile
# - 2006_commercial_total_use_area_percentile
# - 2011_commercial_total_use_area_percentile
# - 2016_commercial_total_use_area_percentile
# - 2023_old__commercial_total_use_area_percentile
# - 1996_hotel_total_use_area_percentile
# - 2001_hotel_total_use_area_percentile
# - 2006_hotel_total_use_area_percentile
# - 2011_hotel_total_use_area_percentile
# - 2016_hotel_total_use_area_percentile
# - 2023_old__hotel_total_use_area_percentile
# - 1996_house_total_use_area_percentile
# - 2001_house_total_use_area_percentile
# - 2006_house_total_use_area_percentile
# - 2011_house_total_use_area_percentile
# - 2016_house_total_use_area_percentile
# - 2023_old__house_total_use_area_percentile
# - 1996_apartment_total_use_area_percentile
# - 2001_apartment_total_use_area_percentile
# - 2006_apartment_total_use_area_percentile
# - 2011_apartment_total_use_area_percentile
# - 2016_apartment_total_use_area_percentile
# - 2023_old__apartment_total_use_area_percentile
# - 1996_logistics_total_use_area_percentile
# - 2001_logistics_total_use_area_percentile
# - 2006_logistics_total_use_area_percentile
# - 2011_logistics_total_use_area_percentile
# - 2016_logistics_total_use_area_percentile
# - 2023_old__logistics_total_use_area_percentile
# - 1996_total_use_area_percentile
# - 2001_total_use_area_percentile
# - 2006_total_use_area_percentile
# - 2011_total_use_area_percentile
# - 2016_total_use_area_percentile
# - 2023_old__total_use_area_percentile
# - diff_building_count
# - diff_office_count
# - diff_commercial_count
# - diff_hotel_count
# - diff_house_count
# - diff_apartment_count
# - diff_logistics_count
# - diff_total_use_area
# - diff_office_total_use_area
# - diff_commercial_total_use_area
# - diff_hotel_total_use_area
# - diff_house_total_use_area
# - diff_apartment_total_use_area
# - diff_logistics_total_use_area
# - diff_total_use_area_percentile
# - diff_office_total_use_area_percentile
# - diff_commercial_total_use_area_percentile
# - diff_hotel_total_use_area_percentile
# - diff_house_total_use_area_percentile
# - diff_apartment_total_use_area_percentile
# - diff_logistics_total_use_area_percentile
# - geometry

# %%
years = [1996, 2001, 2006, 2011, 2016, 2023]
for year in years:
    house_col = f"{year}_house_total_use_area"
    apt_col = f"{year}_apartment_total_use_area"
    total_col = f"{year}_housing_total_use_area"
    tokyo_gdf[total_col] = tokyo_gdf[house_col].fillna(0) + tokyo_gdf[apt_col].fillna(0)
    # Set to NaN if both are NaN
    both_nan = tokyo_gdf[house_col].isna() & tokyo_gdf[apt_col].isna()
    tokyo_gdf.loc[both_nan, total_col] = float('nan')

# %%
# List the new fields (columns ending with '_housing_total_use_area')
new_fields = [col for col in tokyo_gdf.columns if col.endswith('_housing_total_use_area')]
print("New fields:")
for field in new_fields:
    print(f"- {field}")

# Show some of their values
tokyo_gdf[new_fields].head()
# Out:
# New fields:
# - 1996_housing_total_use_area
# - 2001_housing_total_use_area
# - 2006_housing_total_use_area
# - 2011_housing_total_use_area
# - 2016_housing_total_use_area
# - 2023_housing_total_use_area
#    1996_housing_total_use_area  2001_housing_total_use_area  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                  87612.71812                101087.062840
# 3                 124567.82399                159349.128352
# 4                  40731.61528                 46865.451140
#
#    2006_housing_total_use_area  2011_housing_total_use_area  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                114823.492054                 134833.81841
# 3                232998.659129                 241418.05294
# 4                 55806.765863                  58108.71100
#
#    2016_housing_total_use_area  2023_housing_total_use_area
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                 154795.00879                  123005.5030
# 3                 239981.84673                  169668.4005
# 4                  62743.28499                   50536.3970

# %%
for year in years:
    # Define column names for each use category
    commercial_col = f"{year}_commercial_total_use_area"
    logistics_col = f"{year}_logistics_total_use_area"
    hotel_col = f"{year}_hotel_total_use_area"
    other_col = f"{year}_other_total_use_area"
    
    # Combine the three categories, treating NaN as 0, but set to NaN if all are NaN
    tokyo_gdf[other_col] = (
        tokyo_gdf[commercial_col].fillna(0) +
        tokyo_gdf[logistics_col].fillna(0) +
        tokyo_gdf[hotel_col].fillna(0)
    )
    all_nan = (
        tokyo_gdf[commercial_col].isna() &
        tokyo_gdf[logistics_col].isna() &
        tokyo_gdf[hotel_col].isna()
    )
    tokyo_gdf.loc[all_nan, other_col] = float('nan')

# %%
# Select columns to keep: 'KEY_CODE', columns containing 'building_count', 'housing', 'office', or 'other'
cols_to_keep = ['KEY_CODE'] + [col for col in tokyo_gdf.columns if (
    'building_count' in col or 'housing' in col or 'office' in col or 'other' in col
)]
tokyo_slim = tokyo_gdf[cols_to_keep].copy()
tokyo_slim.head()
# Out:
#     KEY_CODE  2023_building_count  2023_office_count  \
# 0  533925552                  2.0                NaN
# 1  533925554                  NaN                NaN
# 2  533925561                664.0               16.0
# 3  533925562               1071.0               15.0
# 4  533925563                557.0                1.0
#
#    2023_office_total_use_area  1996_building_count  2001_building_count  \
# 0                         NaN                  NaN                  NaN
# 1                         NaN                  NaN                  NaN
# 2                   13706.932                529.0                473.0
# 3                    2347.470                967.0                939.0
# 4                     157.120                485.0                485.0
#
#    2006_building_count  2011_building_count  2016_building_count  \
# 0                  NaN                  NaN                  1.0
# 1                  NaN                  NaN                  NaN
# 2                488.0                492.0                584.0
# 3                905.0                901.0               1008.0
# 4                479.0                486.0                529.0
#
#    2023_old__building_count  ...  2006_housing_total_use_area  \
# 0                       1.0  ...                          NaN
# 1                       NaN  ...                          NaN
# 2                     547.0  ...                114823.492054
# 3                     880.0  ...                232998.659129
# 4                     466.0  ...                 55806.765863
#
#    2011_housing_total_use_area  2016_housing_total_use_area  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                 134833.81841                 154795.00879
# 3                 241418.05294                 239981.84673
# 4                  58108.71100                  62743.28499
#
#    2023_housing_total_use_area  1996_other_total_use_area  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                  123005.5030                19409.38366
# 3                  169668.4005                 4493.87552
# 4                   50536.3970                 2001.39100
#
#    2001_other_total_use_area  2006_other_total_use_area  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2               17153.774595               20110.995828
# 3                3109.528341                4700.985586
# 4                1824.047786                  92.178310
#
#    2011_other_total_use_area  2016_other_total_use_area  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                20715.53687                 2629.89450
# 3                 4246.00769                 4070.09452
# 4                  129.16658                  129.25711
#
#    2023_other_total_use_area
# 0                        NaN
# 1                        NaN
# 2                    2816.67
# 3                    3208.36
# 4                     112.95
#
# [5 rows x 59 columns]

# %%
tokyo_slim_gdf = gpd.GeoDataFrame(tokyo_slim, geometry=tokyo_gdf.geometry)
tokyo_slim_gdf.to_file("tokyo_slim.geojson", driver="GeoJSON")
